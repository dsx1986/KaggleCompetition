# %%
import pandas as pd

# %%
destinations = pd.read_csv("~/Documents/KaggleData/Expedia/destinations.csv")

# %%
test = pd.read_csv("~/Documents/KaggleData/Expedia/test.csv")

# %%
train = pd.read_csv("~/Documents/KaggleData/Expedia/train.csv")

# %%
train.head(5)
# Out:
#              date_time  site_name  posa_continent  user_location_country  \
# 0  2014-08-11 07:46:59          2               3                     66
# 1  2014-08-11 08:22:12          2               3                     66
# 2  2014-08-11 08:24:33          2               3                     66
# 3  2014-08-09 18:05:16          2               3                     66
# 4  2014-08-09 18:08:18          2               3                     66
#
#    user_location_region  user_location_city  orig_destination_distance  \
# 0                   348               48862                  2234.2641
# 1                   348               48862                  2234.2641
# 2                   348               48862                  2234.2641
# 3                   442               35390                   913.1932
# 4                   442               35390                   913.6259
#
#    user_id  is_mobile  is_package      ...        srch_children_cnt  \
# ...

# %%
train.shape
# Out:
# (37670293, 24)

# %%
test.head(5)
# Out:
#    id            date_time  site_name  posa_continent  user_location_country  \
# 0   0  2015-09-03 17:09:54          2               3                     66
# 1   1  2015-09-24 17:38:35          2               3                     66
# 2   2  2015-06-07 15:53:02          2               3                     66
# 3   3  2015-09-14 14:49:10          2               3                     66
# 4   4  2015-07-17 09:32:04          2               3                     66
#
#    user_location_region  user_location_city  orig_destination_distance  \
# 0                   174               37449                  5539.0567
# 1                   174               37449                  5873.2923
# 2                   142               17440                  3975.9776
# 3                   258               34156                  1508.5975
# 4                   467               36345                    66.7913
#
# ...

# %%
test.shape
# Out:
# (2528243, 22)

# %%
hotel_cluster_histogram = train["hotel_cluster"].value_counts()

# %%
hotel_cluster_histogram
# Out:
# 91    1043720
# 41     772743
# 48     754033
# 64     704734
# 65     670960
# 5      620194
# 98     589178
# 59     570291
# 42     551605
# 21     550092
# 70     545572
# 18     545284
# 83     534132
# 46     534038
# 25     530591
# 62     518809
# 95     509266
# 28     507016
# 68     503797
# 82     503755
# 37     496061
# 50     489892
# 30     489287
# 9      488328
# 58     483253
# 97     479446
# 16     477868
# 72     457463
# 1      452694
# 99     444887
#        ...
# 19     282893
# 84     278264
# 66     273505
# 38     269246
# 87     260398
# 23     259233
# 12     259022
# 31     257587
# 67     255946
# 43     253578
# 7      252447
# 54     250745
# 92     244343
# 89     243560
# 45     241408
# 49     240124
# 3      225250
# 80     220218
# 60     217919
# 71     216054
# 93     214293
# 86     209054
# 14     192299
# 75     165226
# 24     164127
# 35     139122
# 53     134812
# 88     107784
# 27     105040
# 74      48355
# ...

# %%
test_ids = set(test.user_id.unique())
train_ids = set(train.user_id.unique())
intersection_count = len( test_ids & train_ids)
intersection_count == len(test_ids)
# Out:
# True

# %%
train["date_time"] = pd.to_datetime(train["date_time"])
train["year"] = train["date_time"].dt.year
train["month"] = train["date_time"].dt.month

test["date_time"] = pd.to_datetime(test["date_time"])
test["year"] = test["date_time"].dt.year
test["month"] = test["date_time"].dt.month

# %%
train.head(5)
# Out:
#             date_time  site_name  posa_continent  user_location_country  \
# 0 2014-08-11 07:46:59          2               3                     66
# 1 2014-08-11 08:22:12          2               3                     66
# 2 2014-08-11 08:24:33          2               3                     66
# 3 2014-08-09 18:05:16          2               3                     66
# 4 2014-08-09 18:08:18          2               3                     66
#
#    user_location_region  user_location_city  orig_destination_distance  \
# 0                   348               48862                  2234.2641
# 1                   348               48862                  2234.2641
# 2                   348               48862                  2234.2641
# 3                   442               35390                   913.1932
# 4                   442               35390                   913.6259
#
#    user_id  is_mobile  is_package  ...    srch_destination_id  \
# ...

# %%
test.head(5)
# Out:
#    id           date_time  site_name  posa_continent  user_location_country  \
# 0   0 2015-09-03 17:09:54          2               3                     66
# 1   1 2015-09-24 17:38:35          2               3                     66
# 2   2 2015-06-07 15:53:02          2               3                     66
# 3   3 2015-09-14 14:49:10          2               3                     66
# 4   4 2015-07-17 09:32:04          2               3                     66
#
#    user_location_region  user_location_city  orig_destination_distance  \
# 0                   174               37449                  5539.0567
# 1                   174               37449                  5873.2923
# 2                   142               17440                  3975.9776
# 3                   258               34156                  1508.5975
# 4                   467               36345                    66.7913
#
#    user_id  is_mobile  ...    srch_adults_cnt  srch_children_cnt srch_rm_cnt  \
# ...
